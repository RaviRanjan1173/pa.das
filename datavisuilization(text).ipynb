# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data=pd.read_csv("C:/Users/Ravi Ranjan Kumar/Downloads/Iris.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.info()
plt.xlabel("SepalLength")
plt.ylabel("SepalWidthCm")

### analysis to spicies acording to sepallength and petallength
sns.scatterplot(x=data['SepalLengthCm'],y=data['SepalWidthCm'] ,hue=data['Species'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# <Axes: xlabel='SepalLength', ylabel='SepalWidthCm'>

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#####distribustion of petallength  according to sepal length

sns.barplot(y=data['Species'],x=data['SepalWidthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Species'>

# %%
plt.figure(figsize=(8,4)) 
sns.boxplot(x='Species',y='SepalWidthCm',data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
plt.figure(figsize=(8,4)) 
sns.boxplot(x='Species',y='PetalWidthCm',data=data ,palette='YlGnBu')
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
plt.figure(figsize=(8,4)) 
sns.boxplot(x='Species',y='PetalLengthCm',data=data ,palette='YlGnBu')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
plt.figure(figsize=(8,4)) 
sns.boxplot(x='Species',y='SepalLengthCm',data=data )
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>
